# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sales_082020.csv")
df2= pd.read_csv("currency_rates_082020_EUR.csv")
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %% [markdown]
# ![image%20%287%29.png](attachment:image%20%287%29.png)

# %%
#1 - 2

df2

# %%
df.date=pd.to_datetime(df.date)
df2.date=pd.to_datetime(df2.date)

# %%
df.info()

# %%
df2.info()

# %%
df.describe()

# %%
df.shape

# %%
df2

# %%
#3

df.seller_id.nunique()

# %%
#3

df.seller_id.value_counts()

# %%
df_new = pd.merge(df, df2, how="inner", on=["currency", "date"])
df_new
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# ...

# %%
df=df_new.copy()
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# ...

# %%
df["EUR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EUR'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#4

df["EUR"] = df["price"] / df["rate"]
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# ...

# %%
#4 ### burda bulduğum değerde 10 günlük rate 1 gün gibi kabul ettiğim için exact sonuç vermedi ama günü kurtardı.

df.EUR.sum()

# %%
#5

df.brand.value_counts(dropna = False)

# %%
#6 ####yanlış

#((df.category == "Jewellery") & (df.brand.isna()) | (df.brand == "UNSPECIFIED")).sum()

# %%
df[ ( df.category == "Jewellery") & (df.brand.isnull() ) ]#.product_code.nunique()
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 12      p6nqo9ow69            GB  nssbpcrq             GB  wq0l762madfz
# 13      p6nqo9ow69            GB  nssbpcrq             GB  barsdufpkov1
# 14      p6nqo9ow69            GB  nssbpcrq             GB  sx4v979fwe9g
# 17      pykp4zs8mc            GB  scikolkp             GB  737xf8jztbe3
# 18      o5xp196pcv            GB  scikolkp             GB  737xf8jztbe3
# ...            ...           ...       ...            ...           ...
# 237559  r5yybfohtd           RoW  obj73jrd            RoW  cltpu36u88j9
# 237603  cdg1teu4ci           RoW  qkbj84x9            RoW  57vayo0pe16h
# 237605  akms2z4sfi           RoW  46doai5x            RoW  23m53gbwhy5i
# 237644  5dqjb29gah           RoW  echsgc0o            RoW  gamzhdm6zesg
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
#
#          category brand currency   price       date       rate
# ...

# %%
df[( df.category == "Jewellery") & (df.brand.isnull() ) ].product_code.nunique()
# Out:
# 10931

# %%
#7

((df.brand.value_counts() >= 35) & (df.brand.value_counts() <= 55)).sum()
# Out:
# 81

# %%
(df.groupby('brand')['brand'].count().apply(lambda x: 34 < x < 56)).sum()
# Out:
# 81

# %%
#8

((df.buyer_country == "AU") & (df.category == "Shoes")).sum()
# Out:
# 658

# %%
#9

df.groupby("brand")[["price"]].mean().sort_values(by = "price", ascending = False)
# Out:
#                              price
# brand
# Goyard                  339.363333
# Loewe                   302.043333
# Loeffler Randall        244.840000
# Craig Green             239.940000
# Walter Van Beirendonck  216.180000
# ...                            ...
# MUA                       4.686667
# Max Factor                3.911667
# Bronica                   3.786000
# 36572                     1.120000
# 360 Cashmere              1.120000
#
# [1134 rows x 1 columns]

# %%
df[(df.buyer_country == "GB") & (df.seller_country == "GB")]["price"].sum()
# Out:
# 3184495.5799999996

# %%
df[(df.buyer_country == "GB") & (df.seller_country == "GB")]["EUR"].sum()
# Out:
# 3526745.033129233

# %%
#11

US = df[df.seller_country == "US"]
US[US.buyer_country == "US"][["EUR"]].sum() / US[["EUR"]].sum()
# Out:
# EUR    0.959692
# dtype: float64

# %%
df[(df.seller_country == "US") & (US.buyer_country == "US")].EUR.sum() /df[(df.seller_country == "US")].EUR.sum() *100
# Out:
# 95.96922067159569
